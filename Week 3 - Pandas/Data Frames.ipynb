# %%
import numpy as np
import pandas as pd

from pandas import Series, DataFrame

# %%
import webbrowser #get data from wikipedia nba records
website='https://en.wikipedia.org/wiki/List_of_all-time_NBA_win-loss_records'
webbrowser.open(website)
# Out:
# True

# %%
nba_frame = pd.read_clipboard() #copy the clipboard and add it to a frame
nba_frame
# Out:
#    Rank                   Team     GP    Won   Lost   Pct. First NBA season  \
# 0     1      San Antonio Spurs  3,621  2,227  1,394  0.618          1976–77
# 1     2     Los Angeles Lakers  5,758  3,427  2,331  0.595          1948–49
# 2     3         Boston Celtics  5,868  3,462  2,406  0.590          1946–47
# 3     4              Utah Jazz  3,786  2,060  1,726  0.544          1974–75
# 4     5  Oklahoma City Thunder  4,360  2,349  2,011  0.539          1967–68
#
#     Division
# 0  Southwest
# 1    Pacific
# 2   Atlantic
# 3  Northwest
# 4  Northwest

# %%
nba_frame.columns #check the frame columns list
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Pct.', 'First NBA season',
#        'Division'],
#       dtype='object')

# %%
nba_frame.Team # print a columns list
# Out:
# 0        San Antonio Spurs
# 1       Los Angeles Lakers
# 2           Boston Celtics
# 3                Utah Jazz
# 4    Oklahoma City Thunder
# Name: Team, dtype: object

# %%
nba_frame['First NBA season'] #2nd way to call the columns
# Out:
# 0    1976–77
# 1    1948–49
# 2    1946–47
# 3    1974–75
# 4    1967–68
# Name: First NBA season, dtype: object

# %%
DataFrame(nba_frame, columns=['Team', 'First NBA season', 'Division']) #how to call multiple columns
# Out:
#                     Team First NBA season   Division
# 0      San Antonio Spurs          1976–77  Southwest
# 1     Los Angeles Lakers          1948–49    Pacific
# 2         Boston Celtics          1946–47   Atlantic
# 3              Utah Jazz          1974–75  Northwest
# 4  Oklahoma City Thunder          1967–68  Northwest

# %%
DataFrame(nba_frame, columns=['Team', 'First NBA season', 'Division', 'Players']) #Players is a null column
# Out:
#                     Team First NBA season   Division  Players
# 0      San Antonio Spurs          1976–77  Southwest      NaN
# 1     Los Angeles Lakers          1948–49    Pacific      NaN
# 2         Boston Celtics          1946–47   Atlantic      NaN
# 3              Utah Jazz          1974–75  Northwest      NaN
# 4  Oklahoma City Thunder          1967–68  Northwest      NaN

# %%
nba_frame
# Out:
#    Rank                   Team     GP    Won   Lost   Pct. First NBA season  \
# 0     1      San Antonio Spurs  3,621  2,227  1,394  0.618          1976–77
# 1     2     Los Angeles Lakers  5,758  3,427  2,331  0.595          1948–49
# 2     3         Boston Celtics  5,868  3,462  2,406  0.590          1946–47
# 3     4              Utah Jazz  3,786  2,060  1,726  0.544          1974–75
# 4     5  Oklahoma City Thunder  4,360  2,349  2,011  0.539          1967–68
#
#     Division
# 0  Southwest
# 1    Pacific
# 2   Atlantic
# 3  Northwest
# 4  Northwest

# %%
nba_frame.head(3) # to get data of first 3 columns
# Out:
#    Rank                Team     GP    Won   Lost   Pct. First NBA season  \
# 0     1   San Antonio Spurs  3,621  2,227  1,394  0.618          1976–77
# 1     2  Los Angeles Lakers  5,758  3,427  2,331  0.595          1948–49
# 2     3      Boston Celtics  5,868  3,462  2,406  0.590          1946–47
#
#     Division
# 0  Southwest
# 1    Pacific
# 2   Atlantic

# %%
nba_frame.tail(3) # get bottom 3 columns
# Out:
#    Rank                   Team     GP    Won   Lost   Pct. First NBA season  \
# 2     3         Boston Celtics  5,868  3,462  2,406  0.590          1946–47
# 3     4              Utah Jazz  3,786  2,060  1,726  0.544          1974–75
# 4     5  Oklahoma City Thunder  4,360  2,349  2,011  0.539          1967–68
#
#     Division
# 2   Atlantic
# 3  Northwest
# 4  Northwest

# %%
nba_frame.loc[1] # get the location index for the Lakers data
# Out:
# Rank                                 2
# Team                Los Angeles Lakers
# GP                               5,758
# Won                              3,427
# Lost                             2,331
# Pct.                             0.595
# First NBA season               1948–49
# Division                       Pacific
# Name: 1, dtype: object

# %%
nba_frame['MVP'] = "DeMar DeRozan" # add the MVP row and assign the value
nba_frame
# Out:
#    Rank                   Team     GP    Won   Lost   Pct. First NBA season  \
# 0     1      San Antonio Spurs  3,621  2,227  1,394  0.618          1976–77
# 1     2     Los Angeles Lakers  5,758  3,427  2,331  0.595          1948–49
# 2     3         Boston Celtics  5,868  3,462  2,406  0.590          1946–47
# 3     4              Utah Jazz  3,786  2,060  1,726  0.544          1974–75
# 4     5  Oklahoma City Thunder  4,360  2,349  2,011  0.539          1967–68
#
#     Division            MVP
# 0  Southwest  DeMar DeRozan
# 1    Pacific  DeMar DeRozan
# 2   Atlantic  DeMar DeRozan
# 3  Northwest  DeMar DeRozan
# 4  Northwest  DeMar DeRozan

# %%
nba_frame['MVP'] = np.arange(5) # arange the MVP column

# %%
nba_frame
# Out:
#    Rank                   Team     GP    Won   Lost   Pct. First NBA season  \
# 0     1      San Antonio Spurs  3,621  2,227  1,394  0.618          1976–77
# 1     2     Los Angeles Lakers  5,758  3,427  2,331  0.595          1948–49
# 2     3         Boston Celtics  5,868  3,462  2,406  0.590          1946–47
# 3     4              Utah Jazz  3,786  2,060  1,726  0.544          1974–75
# 4     5  Oklahoma City Thunder  4,360  2,349  2,011  0.539          1967–68
#
#     Division  MVP
# 0  Southwest    0
# 1    Pacific    1
# 2   Atlantic    2
# 3  Northwest    3
# 4  Northwest    4

# %%
team_mvp = Series(["DeMar DeRozan", "LeBron James"], index=[0,1]) # creat mvp series assign values to a specific index

# %%
team_mvp
# Out:
# 0    DeMar DeRozan
# 1     LeBron James
# dtype: object

# %%
nba_frame['MVP'] = team_mvp #assign the MVP Series to the NBA frame MVP column
nba_frame
# Out:
#    Rank                   Team     GP    Won   Lost   Pct. First NBA season  \
# 0     1      San Antonio Spurs  3,621  2,227  1,394  0.618          1976–77
# 1     2     Los Angeles Lakers  5,758  3,427  2,331  0.595          1948–49
# 2     3         Boston Celtics  5,868  3,462  2,406  0.590          1946–47
# 3     4              Utah Jazz  3,786  2,060  1,726  0.544          1974–75
# 4     5  Oklahoma City Thunder  4,360  2,349  2,011  0.539          1967–68
#
#     Division            MVP
# 0  Southwest  DeMar DeRozan
# 1    Pacific   LeBron James
# 2   Atlantic            NaN
# 3  Northwest            NaN
# 4  Northwest            NaN

# %%
del nba_frame['MVP'] # delete the MVP column
nba_frame
# Out:
#    Rank                   Team     GP    Won   Lost   Pct. First NBA season
# 0     1      San Antonio Spurs  3,621  2,227  1,394  0.618          1976–77
# 1     2     Los Angeles Lakers  5,758  3,427  2,331  0.595          1948–49
# 2     3         Boston Celtics  5,868  3,462  2,406  0.590          1946–47
# 3     4              Utah Jazz  3,786  2,060  1,726  0.544          1974–75
# 4     5  Oklahoma City Thunder  4,360  2,349  2,011  0.539          1967–68

# %%
data = {'City':['SA', 'LA', 'BOS'], 'Population':[1547253, 3967000, 692600]} # create dictonary

# %%
city_frame = DataFrame(data) #create a new frame for cities
city_frame
# Out:
#   City  Population
# 0   SA     1547253
# 1   LA     3967000
# 2  BOS      692600
